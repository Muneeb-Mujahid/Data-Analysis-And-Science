# %% [markdown]
# # EDA on Game of Thrones Data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Added data set of battles

# %%
battle = pd.read_csv(r'C:\\Users\munee\Downloads\Data-Science-Course-main\battles.csv')

# %%
battle.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
battle.shape
# Out:
# (38, 25)

# %% [markdown]
# ### Replace all NaN column to None

# %%
battle.isnull().sum()
# Out:
# name                   0
# year                   0
# battle_number          0
# attacker_king          2
# defender_king          3
# attacker_1             0
# attacker_2            28
# attacker_3            35
# attacker_4            36
# defender_1             1
# defender_2            36
# defender_3            38
# defender_4            38
# attacker_outcome       1
# battle_type            1
# major_death            1
# major_capture          1
# attacker_size         14
# defender_size         19
# attacker_commander     1
# defender_commander    10
# summer                 1
# location               1
# region                 0
# note                  33
# dtype: int64

# %%
battle.replace(np.nan, "None",inplace=True)

# %%
battle.isnull().sum()
# Out:
# name                  0
# year                  0
# battle_number         0
# attacker_king         0
# defender_king         0
# attacker_1            0
# attacker_2            0
# attacker_3            0
# attacker_4            0
# defender_1            0
# defender_2            0
# defender_3            0
# defender_4            0
# attacker_outcome      0
# battle_type           0
# major_death           0
# major_capture         0
# attacker_size         0
# defender_size         0
# attacker_commander    0
# defender_commander    0
# summer                0
# location              0
# region                0
# note                  0
# dtype: int64

# %%
battle.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister       None
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister       None
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister       None
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark       None
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death major_capture  \
# 0       None       None      Tully  ...         1.0           0.0
# ...

# %% [markdown]
# ### Rename attacker 1 as primary attracker

# %%
battle.rename(columns={'attacker_1':'primary_attacker'},inplace=True)
battle.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king primary_attacker  \
# 0  Joffrey/Tommen Baratheon                Robb Stark        Lannister
# 1  Joffrey/Tommen Baratheon                Robb Stark        Lannister
# 2  Joffrey/Tommen Baratheon                Robb Stark        Lannister
# 3                Robb Stark  Joffrey/Tommen Baratheon            Stark
# 4                Robb Stark  Joffrey/Tommen Baratheon            Stark
#
#   attacker_2 attacker_3 attacker_4 defender_1  ... major_death major_capture  \
# 0       None       None       None      Tully  ...         1.0           0.0
# ...

# %% [markdown]
# ### Rename defender 1 as primary defender

# %%
battle.rename(columns={'defender_1':'primary_defender'},inplace=True)
battle.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king primary_attacker  \
# 0  Joffrey/Tommen Baratheon                Robb Stark        Lannister
# 1  Joffrey/Tommen Baratheon                Robb Stark        Lannister
# 2  Joffrey/Tommen Baratheon                Robb Stark        Lannister
# 3                Robb Stark  Joffrey/Tommen Baratheon            Stark
# 4                Robb Stark  Joffrey/Tommen Baratheon            Stark
#
#   attacker_2 attacker_3 attacker_4 primary_defender  ... major_death  \
# 0       None       None       None            Tully  ...         1.0
# 1       None       None       None        Baratheon  ...         1.0
# ...

# %% [markdown]
# ### count the value of attacker king

# %%
battle['attacker_king'].value_counts()
# Out:
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# None                         2
# Name: attacker_king, dtype: int64

# %% [markdown]
# ### count the value of locations

# %%
battle['location'].value_counts()
# Out:
# Riverrun                                3
# Winterfell                              3
# Harrenhal                               2
# Storm's End                             2
# Darry                                   2
# Moat Cailin                             2
# Deepwood Motte                          2
# Torrhen's Square                        2
# The Twins                               1
# Seagard                                 1
# Castle Black                            1
# Shield Islands                          1
# Saltpans                                1
# None                                    1
# Ryamsport, Vinetown, Starfish Harbor    1
# Dragonstone                             1
# Ruby Ford                               1
# Golden Tooth                            1
# Duskendale                              1
# King's Landing                          1
# Crag                                    1
# Mummer's Ford                           1
# ...

# %% [markdown]
# ### Graphically representation of attacker king and attacker size

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.barplot(x='attacker_king',y='attacker_size',data=battle)
plt.show()

# %% [markdown]
# ### Graphically representation of defender king and defender size

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.barplot(x='defender_king',y='defender_size',data=battle)
plt.show()

# %% [markdown]
# ### Graphically representation of battle types

# %%
sns.countplot(x=battle['attacker_king'],hue=battle['battle_type'])
plt.show()

# %% [markdown]
# ### Added another data set which consist of deaths

# %%
death = pd.read_csv(r'C:\\Users\munee\Downloads\Data-Science-Course-main\character-deaths.csv')
death.head()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)             None       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
death.shape
# Out:
# (917, 13)

# %% [markdown]
# ### Count the value of gender 1 is represent male characters and 0 is represent female characters

# %%
death['Gender'].value_counts()
# Out:
# 1    760
# 0    157
# Name: Gender, dtype: int64

# %% [markdown]
# ### Count the value of Nobility 1 is represent male characters and 0 is represent female characters

# %%
death['Nobility'].value_counts()
# Out:
# 0    487
# 1    430
# Name: Nobility, dtype: int64

# %% [markdown]
# ### Graphically representation of Death year

# %%
sns.countplot(death['Death Year'])
plt.show()
# Out:
# C:\Users\munee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(x='Death Year', data = death)
plt.show()
